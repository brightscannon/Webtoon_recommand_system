# %% [markdown]
# ### Modeling
# - total score(총 평점), genre(13개 장르), episode_cnt(최종회차, 총 회차수), total_comments(총 댓글 수), episode_mean_score(회차 평균 평점), like_count(웹툰 하트 수)

# %%
info.to_csv("data_Juno/webtoon_naver_info_by_genres_seperated.csv", index=False)

# %%
info = pd.read_csv("data_Juno/webtoon_naver_info_by_genres_seperated.csv")
info.tail()
# Out:
#      unique_id    title_x   author  total_score  \
# 740     622643    진눈깨비 소년  쥬드프라이데이         9.97
# 741     703840  한국만화 1990     웹툰작가         9.75
# 742     336945    길에서 만나다  쥬드프라이데이         9.75
# 743     515883  사또(Satto)      최윤진         9.80
# 744     347685  슈퍼트리오 시즌2      황미나         7.36
#
#                                              main_link  \
# 740  https://comic.naver.com/webtoon/list.nhn?title...
# 741  https://comic.naver.com/webtoon/list.nhn?title...
# 742  https://comic.naver.com/webtoon/list.nhn?title...
# 743  https://comic.naver.com/webtoon/list.nhn?title...
# 744  https://comic.naver.com/webtoon/list.nhn?title...
#
#                                             image_link update_date episode  \
# 740  https://shared-comic.pstatic.net/thumb/webtoon...  2018.08.30    None
# 741  https://shared-comic.pstatic.net/thumb/webtoon...  2018.05.17    None
# 742  https://shared-comic.pstatic.net/thumb/webtoon...  2013.01.17    None
# ...

# %%
info.pay.value_counts()
# Out:
# 0    500
# 1    245
# Name: pay, dtype: int64

# %%
info[info.total_score > 9.98]
# Out:
#      unique_id title_x author  total_score  \
# 384     670144    가담항설     랑또         9.99
# 430     713872   연의 편지    조현아         9.99
#
#                                              main_link  \
# 384  https://comic.naver.com/webtoon/list.nhn?title...
# 430  https://comic.naver.com/webtoon/list.nhn?title...
#
#                                             image_link update_date episode  \
# 384  https://shared-comic.pstatic.net/thumb/webtoon...  2018.08.29    None
# 430  https://shared-comic.pstatic.net/thumb/webtoon...  2018.09.01    None
#
#     omnibus  story    ...      pure sensibility thrill  historical sports pay  \
# 384    None  story    ...      None        None   None  historical   None   0
# 430    None  story    ...      pure        None   None        None   None   0
#
#     episode_cnt total_comments episode_score like_count
# 384         138         222248      9.986232     200740
# 430           4          12238      9.987500     157253
#
# [2 rows x 25 columns]

# %%
episode = pd.read_csv("data_Juno/episode_per_webtoon_naver.csv")
episode.tail()
# Out:
#       title                                         image_link  \
# 54723    까뱅  https://shared-comic.pstatic.net/thumb/webtoon...
# 54724    까뱅  https://shared-comic.pstatic.net/thumb/webtoon...
# 54725    까뱅  https://shared-comic.pstatic.net/thumb/webtoon...
# 54726    까뱅  https://shared-comic.pstatic.net/thumb/webtoon...
# 54727    까뱅  https://shared-comic.pstatic.net/thumb/webtoon...
#
#                      episode  titleid  episode_cnt  total_comments  \
# 54723     GGAVANG 5화 <침투(2)>    22073            5             419
# 54724     GGAVANG 4화 <침투(1)>    22073            4             384
# 54725        GGAVANG 3화 <화산>    22073            3             507
# 54726  GGAVANG 2화 <레이저 빔(2)>    22073            2             577
# 54727  GGAVANG 1화 <레이저 빔(1)>    22073            1             945
#
#        episode_score  episode_like upload_date
# 54723           8.93             7  2007-01-22
# 54724           9.00             6  2007-01-22
# ...
