# %%
import requests
import json
from bs4 import BeautifulSoup
import time

# %%
url = "https://apis.naver.com/commentBox/cbox/web_naver_list_jsonp.json?ticket=comic&templateId=webtoon&pool=cbox3&lang=ko&country=KR&objectId=641253_50&categoryId=&pageSize=1000&indexSize=10&page=1&sort=best"

# %%
header = {
    'Host' : "apis.naver.com",
    'referer' : "https://comic.naver.com/comment/comment.nhn?titleId=641253&no=50",
    'content-type' : "application/json"
}
response = requests.get(url, headers=header)
dom = BeautifulSoup(response.content, 'html.parser')
# json.loads(dom)
one = dom.text.find('(') + 1
two = dom.text.find(');')

dom.text[one:two]

content = json.loads(dom.text[one:two])
# dom.text[one:two]
# json.loads(dom.text[one:two])
# content
comments = content['result']['commentList']
# comments

# %%
comments[0]
# Out:
# {'ticket': 'comic',
#  'objectId': '641253_50',
#  'categoryId': '*',
#  'templateId': 'webtoon',
#  'commentNo': 225493833,
#  'parentCommentNo': 225493833,
#  'replyLevel': 1,
#  'replyCount': 0,
#  'replyAllCount': 0,
#  'replyPreviewNo': None,
#  'replyList': None,
#  'imageCount': 0,
#  'imageList': None,
#  'imagePathList': None,
#  'imageWidthList': None,
#  'imageHeightList': None,
#  'commentType': 'txt',
#  'stickerId': None,
#  'sticker': None,
#  'sortValue': 1446128251769,
#  'contents': '아무도 50화를 축하해주지 않네요 100회까지.몸 조리 잘하시고 좋은 만화 많이 그려 쥬세요',
#  'userIdNo': None,
#  'exposedUserIp': None,
#  'lang': 'ko',
#  'country': 'KR',
#  'idType': 'naver',
#  'idProvider': 'naver',
#  'userName': '이승환',
#  'userProfileImage': '',
#  'profileType': 'naver',
#  'modTime': '2016-07-11T18:36:48+0900',
#  'modTimeGmt': '2016-07-11T09:36:48+0000',
#  'regTime': '2015-10-29T23:17:31+0900',
#  'regTimeGmt': '2015-10-29T14:17:31+0000',
#  'sympathyCount': 93932,
#  'antipathyCount': 1659,
#  'userBlind': False,
#  'hideReplyButton': False,
#  'status': 0,
#  'mine': False,
#  'best': True,
#  'mentions': None,
#  'toUser': None,
#  'userStatus': 0,
#  'categoryImage': None,
#  'open': False,
#  'levelCode': None,
#  'grades': None,
#  'sympathy': False,
#  'antipathy': False,
#  'snsList': None,
#  'metaInfo': None,
#  'extension': None,
#  'audioInfoList': None,
#  'translation': None,
#  'report': None,
#  'middleBlindReport': False,
#  'spamInfo': None,
#  'userHomepageUrl': None,
#  'defamation': False,
#  'blindReport': False,
#  'serviceId': None,
#  'maskedUserId': 'lsh3****',
#  'maskedUserName': '이승****',
#  'profileUserId': None,
#  'validateBanWords': False,
#  'manager': False,
#  'expose': True,
#  'deleted': False,
#  'visible': True,
#  'secret': False,
#  'blind': False,
#  'exposeByCountry': False,
#  'virtual': False,
#  'containText': True,
#  'anonymous': False}

# %%
content['result']['pageModel']
# Out:
# {'page': 1,
#  'pageSize': 100,
#  'indexSize': 10,
#  'startRow': 1,
#  'endRow': 100,
#  'totalRows': 22728,
#  'startIndex': 0,
#  'totalPages': 228,
#  'firstPage': 1,
#  'prevPage': 0,
#  'nextPage': 2,
#  'lastPage': 10,
#  'current': None,
#  'moveToLastPage': False,
#  'moveToComment': False,
#  'moveToLastPrev': False}

# %%
url = "https://apis.naver.com/commentBox/cbox/web_naver_list_jsonp.json?ticket=comic&templateId=webtoon&pool=cbox3&_callback=jQuery112406650273247043268_1535940803589&lang=ko&country=KR&objectId=651673_222&categoryId=&pageSize=22728&startRow=1&groupId=&listType=OBJECT&pageType=default&page=1&initialize=true&userType=&useAltSort=true&replyPageSize=10&_=1535940803590"

# %%
header = {
    'Host' : "apis.naver.com",
    'Referer' : "https://comic.naver.com/comment/comment.nhn?titleId=651673&no=222",
    'Content-Type' : "application/javascript"
}
response = requests.get(url, headers=header)
dom = BeautifulSoup(response.content, 'html.parser')
# json.loads(dom)
one = dom.text.find('(') + 1
two = dom.text.find(');')

dom.text[one:two]

content = json.loads(dom.text[one:two])
# dom.text[one:two]
# json.loads(dom.text[one:two])
# content
# comments = content['result']['commentList']
# print(comments[0]['userName'])
# print(comments[0]['contents'])
# print(comments[0]['userIdNo'])
# print(comments[0]['modTime'])
# print(comments[0]['maskedUserId'])
# print(comments[0]['sympathyCount'])
# print(comments[0]['antipathyCount'])

comments = content['result']['count']['comment']
dom.text[one:-2]
# Out:
# '{"success":true,"code":"1000","message":"요청을 성공적으로 처리하였습니다.","lang":"ko","country":"KR","result":{"sort":"BEST","count":{"comment":7735,"reply":0,"exposeCount":7735,"delCommentByUser":0,"delCommentByMon":0,"blindCommentByUser":0,"blindReplyByUser":0,"total":7735},"config":{"useSnsLogin":false,"lineFeedOn":false,"useBest":false,"useVote":true,"useVoteSelf":false,"useVoteGoodOnly":false,"useReport":true,"useCommonReport":true,"reportAuthority":"ALL","useDeleteOnManagerReport":false,"useReportSecret":false,"useSort":true,"sortTypes":["BEST","NEW"],"defaultSort":"BEST","useByteLength":false,"useReply":false,"useReplyOnReply":false,"pageAfterReply":null,"maxReplyWriteBoxCount":0,"useAutoRefresh":false,"useMention":false,"min":1,"max":500,"useSticker":false,"stickerOnly":false,"stickerSupportedCategories":null,"stickerDefaultCategory":null,"stickerCategory":null,"stickerContentsUrl":null,"stickerKeyUrl":null,"stickerTabUrl":null,"stickerType":null,"stickerText":false,"stickerMarketUrl":null,"stickerMobileResize":false,"useProfile":false,"dynamicProfile":false,"profileImageAreas":["LIST"],"profileEmptyImage":null,"displayMaskedUserId":true,"useManager":false,"managerDelete":false,"managerBlock":false,"managerNotice":false,"contentsManagerIcon":false,"secretComment":false,"exposureConfig":false,"deleteAllAfterBlock":false,"useFold":true,"replyPreviewCount":0,"maxImageUploadCount":0,"maxImageUploadFileSize":0,"imageAutoRotate":false,"autoRefreshTime":0,"autoRefreshDefaultOff":false,"autoRefreshChat":false,"maxChatFPS":0,"commentModify":false,"useCommentModify":false,"useViewAll":true,"useSnsComment":false,"snsCommentDefaultOn":false,"useUserLevel":false,"useUserBlind":false,"maxUserBlindCount":0,"anyUseImageExpose":false,"useImageComment":false,"useUrlLink":false,"useCommentListIncludeDelete":true,"useStats":false,"statsMinCount":0,"useUserEnvStats":false,"countryStatsMinCount":0,"useConcurrentStats":false,"useVoteStats":false,"useGpopCache":false,"useEnterSubmit":false,"useListReverse":false,"useTranslation":false,"useDeletedList":false,"useAudio":false,"combinedDeletedList":false,"displayDeletedList":false,"applyChangedNotice":false,"useUserCommentUi":false,"userSortTypes":[],"useMentionLegacyFormat":false,"useMentionWrite":false,"mentionMaxCount":0,"useSecret":false,"useIdPenaltyLayer":false,"photoInfraUploadDomain":null,"photoInfraSelectDomainHttp":null,"photoInfraSelectDomainHttps":null,"pcTempThumbnailType":"ff80_80","mobileTempThumbnailType":"ff50_50","realnameVerificationBlock":false,"realnameVerificationMessage":null,"useBlindByReport":false,"keepTextareaOnRestriction":null,"displayIndividualBlindOnly":false,"hashtagMaxLength":20,"useDualPagination":false,"blindReportReasonList":null},"exposureConfig":{"reason":null,"status":"COMMENT_ON"},"bestList":[],"userInfo":{},"pageModel":{"page":1,"pageSize":100,"indexSize":10,"startRow":1,"endRow":100,"totalRows":100,"startIndex":0,"totalPages":1,"firstPage":1,"prevPage":0,"nextPage":0,"lastPage":1,"current":null,"moveToLastPage":false,"moveToComment":false,"moveToLastPrev":false},"commentList":[{"ticket":"comic","objectId":"651673_222","categoryId":"29_170616212208","templateId":"default","commentNo":325924786,"parentCommentNo":325924786,"replyLevel":1,"replyCount":0,"replyAllCount":0,"replyPreviewNo":null,"replyList":null,"imageCount":0,"imageList":null,"imagePathList":null,"imageWidthList":null,"imageHeightList":null,"commentType":"txt","stickerId":null,"sticker":null,"sortValue":1497661915862,"contents":"우리의 이성이 얼마나 대단한 존재인지 말해주는 장면임. 저걸 억누른다는 건 이성세포가 일당 백으로 싸우고 있는 중이란 의미.","userIdNo":"29Boa","exposedUserIp":null,"lang":"ko","country":"KR","idType":"naver","idProvider":"naver","userName":"그린","userProfileImage":"https://profile-phinf.pstatic.net/07093/186de70638eabb0baf344f2b4b5ec80b2cc39469b480afabf3be5106cde3dc3c.jpg","profileType":"naver","modTime":"2017-06-17T10:11:55+0900","modTimeGmt":"2017-06-17T01:11:55+0000","regTime":"2017-06-17T10:11:55+0900","regTimeGmt":"2017-06-17T01 ...

# %%
content['result']['count']['comment']
# Out:
# 22728

# %%
len(comments)
# Out:
# 100

# %%
print(response.geturl()) # https://m.daum.net/?nil_top=mobile
print(response.info()) # 응답해더 값
# Out:
# https://apis.naver.com/commentBox/cbox/web_naver_list_jsonp.json?ticket=comic&templateId=webtoon&pool=cbox3&_callback=jQuery112405412239067839208_1535901080196&lang=ko&country=KR&objectId=570503_1&categoryId=&pageSize=15&indexSize=10&groupId=&listType=OBJECT&pageType=default&page=1&initialize=true&userType=&useAltSort=true&replyPageSize=10&_=1535901080197
# Server: nginx
# Date: Sun, 02 Sep 2018 15:15:13 GMT
# Content-Type: application/javascript; charset=UTF-8
# Content-Length: 187
# Connection: close
# Vary: Accept-Encoding
# Cache-Control: no-cache, no-store, proxy-revalidate, max-age=0
# Pragma: no-cache
# Expires: Thu, 01 Jan 1970 00:00:00 GMT

# %% [markdown]
# ### 댓글 크롤링
# - url 만들어주는 함수(titleid + '_' + no)
# - 전체 댓글갯수를 고려해서 for문을 돌려야 한다.
# - 댓글 따오는 형식 : 웹툰명, 회차, 닉네임, 괄호+아이디, 유저고유아이디(?) ,댓글내용, 추천수, 싫어요 수, 작성일자

# %%
import requests
import json
from bs4 import BeautifulSoup
import time

# %%
def make_url(titleid, no, page):
    objectid = str(titleid) + "_" + str(no)
    return "https://apis.naver.com/commentBox/cbox/web_naver_list_jsonp.json?ticket=comic&templateId=webtoon&pool=cbox3&lang=ko&country=KR&objectId=" + str(objectid) + "&categoryId=&pageSize=100&page=" + str(page) + "&sort=NEW"

# %%
df = pd.read_csv('data_Juno/episode_per_webtoon_naver.csv')
df.tail()
# Out:
#            title                                         image_link  \
# 54691  슈퍼트리오 시즌2  https://shared-comic.pstatic.net/thumb/webtoon...
# 54692  슈퍼트리오 시즌2  https://shared-comic.pstatic.net/thumb/webtoon...
# 54693  슈퍼트리오 시즌2  https://shared-comic.pstatic.net/thumb/webtoon...
# 54694  슈퍼트리오 시즌2  https://shared-comic.pstatic.net/thumb/webtoon...
# 54695  슈퍼트리오 시즌2  https://shared-comic.pstatic.net/thumb/webtoon...
#
#                      episode  titleid  episode_cnt
# 54691     Part 9. 의천검 탈취작전 1   347685            6
# 54692  Part 8. 쌍감자 체포 프로젝트 2   347685            5
# 54693  Part 8. 쌍감자 체포 프로젝트 1   347685            4
# 54694      Part 7. 일천불의 화가 2   347685            3
# 54695      Part 7. 일천불의 화가 1   347685            2

# %%
df[['titleid','episode_cnt']].values
# Out:
# array([[651673,    336],
#        [651673,    335],
#        [651673,    334],
#        ...,
#        [347685,      4],
#        [347685,      3],
#        [347685,      2]], dtype=int64)

# %%
def cal_page(titleid,no,page=1):
    url = make_url(titleid, no, page)
    header = {
    'Host' : "apis.naver.com",
    'Referer' : "https://comic.naver.com/comment/comment.nhn?titleId=" + str(titleid) + "&no=" + str(no),
    'Content-Type' : "application/javascript"
    }
    response = requests.get(url, headers=header)
    dom = BeautifulSoup(response.content, 'html.parser')
    
    one = dom.text.find('(') + 1
#     two = dom.text.find(');')
    
    content = json.loads(dom.text[one:-2])
    comments = content['result']['count']['comment']
    return int(comments)

# %%
cal_page(651673,222)
# Out:
# 7735

# %%
# 네이버 웹툰 댓글 크롤링 함수화
import requests
import json
from bs4 import BeautifulSoup
import time
from IPython.display import clear_output # clear_output() 으로 아웃풋 제거 가능

def get_comment(ls):
    
    dic = {}
    dic['title'] = []
    dic['episode'] = []
    dic['nickname'] = []
    dic['bracket_id'] = []
    dic['comment'] = []
    dic['like_cnt'] = []
    dic['dislike_cnt'] = []
    dic['date'] = []
    dic['user_id'] = []
    
    titleid, no = ls[0], ls[1]
    total_page = cal_page(titleid, no)
    print("total_pages(raw):",total_page)
    total_page = (total_page // 100) + 1 if total_page % 100 != 0 else (total_page // 100) 
    check = []
    print("total_pages:",total_page)
    try:
        for page in range(1,total_page + 1):
            url = make_url(titleid, no, page)

            header = {
            'Host' : "apis.naver.com",
            'Referer' : "https://comic.naver.com/comment/comment.nhn?titleId=" + str(titleid) + "&no=" + str(no),
            'Content-Type' : "application/javascript"
            }
            try:
                response = requests.get(url, headers=header)
                dom = BeautifulSoup(response.content, 'html.parser')
            except:
                print("Server reject...wait 15 seconds")
                time.sleep(15)
                response = requests.get(url, headers=header)
                dom = BeautifulSoup(response.content, 'html.parser')
                
            one = dom.text.find('(') + 1
#             two = dom.text.find(');')

            content = json.loads(dom.text[one:-2])
            comments = content['result']['commentList']

            # comments[0]['userName']
            # comments[0]['contents']
            # comments[0]['userIdNo']
            # comments[0]['modTime']
            # comments[0]['maskedUserId']
            # comments[0]['sympathyCount']
            # comments[0]['antipathyCount']  
            for i in range(100):
                try:
                    dic['bracket_id'].append(comments[i]['maskedUserId'])
                    dic['comment'].append(comments[i]['contents'])
                    dic['like_cnt'].append(comments[i]['sympathyCount'])
                    dic['dislike_cnt'].append(comments[i]['antipathyCount'])
                    dic['date'].append(comments[i]['modTime'])
                    try:
                        dic['nickname'].append(comments[i]['userName'])
                    except:
                        dic['nickname'].append("None")
                    
                    try:
                        dic['user_id'].append(comments[i]['userIdNo'])
                    except:
                        dic['user_id'].append("None")
                    dic['title'].append(df[df.titleid == titleid].title.values[0])
                    dic['episode'].append(no)
                except:
                    break
                    
            print('.', end='')
            if page % 10 == 0:
                print("(",page,")",end="")
        time.sleep(3)
    except:
        check.append({'titleid':titleid, 'no':no})
        
    df_new = pd.DataFrame(dic)
    return df_new, check

# %%
import getpass
from sqlalchemy import *
import sqlalchemy
import pickle
from sqlalchemy.orm import sessionmaker
from sqlalchemy.ext.declarative import declarative_base
import MySQLdb
from sqlalchemy import create_engine

myid = getpass.getpass("input DB id : ")
mypw = getpass.getpass("input DB pw : ")
SQLALCHEMY_DATABASE_URI = 'mysql://'+myid+':'+mypw+'@rds-juno.civpw0n2c5wo.ap-northeast-2.rds.amazonaws.com/naver_webtoon?charset=utf8mb4'

engine = sqlalchemy.create_engine(SQLALCHEMY_DATABASE_URI,encoding='utf-8')
# Out:
# input DB id : ········
# input DB pw : ········

# %%
error = []
ls_all = df[['titleid','episode_cnt']].values
len(ls_all)
# Out:
# 54696

# %%
#총 갯수 54696개
for i in range(119,121):
    ls = ls_all[i]
    clear_output()
    print('now working :',i, 'nd // titleid : ',ls[0], "no : ", ls[1])
    df_comment,check = get_comment(ls)
    if len(check) == 0:
        print("complete!")
        df_comment.to_sql("webtoon_comment", engine, if_exists="append")
    else:
        error.append(check)
        print("error occured...")
# Out:
# now working : 119 nd // titleid :  651673 no :  215
# ---------------------------------------------------------------------------
# SysCallError                              Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\urllib3\contrib\pyopenssl.py in wrap_socket(self, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname)
#     443             try:
# --> 444                 cnx.do_handshake()
#     445             except OpenSSL.SSL.WantReadError:
#
# C:\ProgramData\Anaconda3\lib\site-packages\OpenSSL\SSL.py in do_handshake(self)
#    1906         result = _lib.SSL_do_handshake(self._ssl)
# -> 1907         self._raise_ssl_error(self._ssl, result)
#    1908
#
# C:\ProgramData\Anaconda3\lib\site-packages\OpenSSL\SSL.py in _raise_ssl_error(self, ssl, result)
#    1631                         raise SysCallError(errno, errorcode.get(errno))
# -> 1632                 raise SysCallError(-1, "Unexpected EOF")
#    1633             else:
#
# SysCallError: (-1, 'Unexpected EOF')
#
# During handling of the above exception, another exception occurred:
#
# SSLError                                  Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     599                                                   body=body, headers=headers,
# --> 600                                                   chunked=chunked)
#     601
#
# C:\ProgramData\Anaconda3\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     342         try:
# --> 343             self._validate_conn(conn)
#     344         except (SocketTimeout, BaseSSLError) as e:
#
# C:\ProgramData\Anaconda3\lib\site-packages\urllib3\connectionpool.py in _validate_conn(self, conn)
#     848         if not getattr(conn, 'sock', None):  # AppEngine might not have  `.sock`
# --> 849             conn.connect()
#     850
#
# C:\ProgramData\Anaconda3\lib\site-packages\urllib3\connection.py in connect(self)
#     355             server_hostname=hostname,
# --> 356             ssl_context=context)
#     357
#
# C:\ProgramData\Anaconda3\lib\site-packages\urllib3\util\ssl_.py in ssl_wrap_socket(sock, keyfile, certfile, cert_reqs, ca_certs, server_hostname, ssl_version, ciphers, ssl_context, ca_cert_dir)
#     358         if HAS_SNI and server_hostname is not None:
# --> 359             return context.wrap_socket(sock, server_hostname=server_hostname)
#     360
#
# C:\ProgramData\Anaconda3\lib\site-packages\urllib3\contrib\pyopenssl.py in wrap_socket(self, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname)
#     449             except OpenSSL.SSL.Error as e:
# --> 450                 raise ssl.SSLError('bad handshake: %r' % e)
#     451             break
#
# SSLError: ("bad handshake: SysCallError(-1, 'Unexpected EOF')",)
#
# During handling of the above exception, another exception occurred:
#
# MaxRetryError                             Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     444                     retries=self.max_retries,
# --> 445                     timeout=timeout
#     446                 )
#
# C:\ProgramData\Anaconda3\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     637             retries = retries.increment(method, url, error=e, _pool=self,
# --> 638                                         _stacktrace=sys.exc_info()[2])
#     639             retries.sleep()
#
# C:\ProgramData\Anaconda3\lib\site-packages\urllib3\util\retry.py in increment(self, method, url, response, error, _pool, _stacktrace)
#     397         if new_retry.is_exhausted():
# --> 398             raise MaxRetryError(_pool, url, error or ResponseError(cause))
#     399
#
# MaxRetryError: HTTPSConnectionPool(host='apis.naver.com', port=443): Max retries exceeded with url: /commentBox/cbox/web_naver_list_jsonp.json?ticket=comic&templateId=webtoon&pool=cbox3&lang=ko&country=KR&objectId=651673_215&categoryId=&pageSize=100&page=1&sort=NEW (Caused by SSLError(SSLError("bad handshake: SysCallError(-1, 'Unexpected EOF')",),))
#
# During handling of the above exception, another exception occurred:
#
# SSLError                                  Traceback (most recent call last)
# <ipython-input-74-df32a73db651> in <module>()
#       4     clear_output()
#       5     print('now working :',i, 'nd // titleid : ',ls[0], "no : ", ls[1])
# ----> 6     df_comment,check = get_comment(ls)
#       7     if len(check) == 0:
#       8         print("complete!")
#
# <ipython-input-73-a4d6742e96d6> in get_comment(ls)
#      20
#      21     titleid, no = ls[0], ls[1]
# ---> 22     total_page = cal_page(titleid, no)
#      23     print("total_pages(raw):",total_page)
#      24     total_page = (total_page // 100) + 1 if total_page % 100 != 0 else (total_page // 100)
#
# <ipython-input-67-1115ced37c1e> in cal_page(titleid, no, page)
#       6     'Content-Type' : "application/javascript"
#       7     }
# ----> 8     response = requests.get(url, headers=header)
#       9     dom = BeautifulSoup(response.content, 'html.parser')
#      10
#
# C:\ProgramData\Anaconda3\lib\site-packages\requests\api.py in get(url, params, **kwargs)
#      70
#      71     kwargs.setdefault('allow_redirects', True)
# ---> 72     return request('get', url, params=params, **kwargs)
#      73
#      74
#
# C:\ProgramData\Anaconda3\lib\site-packages\requests\api.py in request(method, url, **kwargs)
#      56     # cases, and look like a memory leak in others.
#      57     with sessions.Session() as session:
# ---> 58         return session.request(method=method, url=url, **kwargs)
#      59
#      60
#
# C:\ProgramData\Anaconda3\lib\site-packages\requests\sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     510         }
#     511         send_kwargs.update(settings)
# --> 512         resp = self.send(prep, **send_kwargs)
#     513
#     514         return resp
#
# C:\ProgramData\Anaconda3\lib\site-packages\requests\sessions.py in send(self, request, **kwargs)
#     620
#     621         # Send the request
# --> 622         r = adapter.send(request, **kwargs)
#     623
#     624         # Total elapsed time of the request (approximately)
#
# C:\ProgramData\Anaconda3\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     509             if isinstance(e.reason, _SSLError):
#     510                 # This branch is for urllib3 v1.22 and later.
# --> 511                 raise SSLError(e, request=request)
#     512
#     513             raise ConnectionError(e, request=request)
#
# SSLError: HTTPSConnectionPool(host='apis.naver.com', port=443): Max retries exceeded with url: /commentBox/cbox/web_naver_list_jsonp.json?ticket=comic&templateId=webtoon&pool=cbox3&lang=ko&country=KR&objectId=651673_215&categoryId=&pageSize=100&page=1&sort=NEW (Caused by SSLError(SSLError("bad handshake: SysCallError(-1, 'Unexpected EOF')",),))

# %%
for k in dic.keys():
    print("key : ", k, "length : ", len(dic[k]))
# Out:
# key :  title length :  8624
# key :  episode length :  8624
# key :  nickname length :  8624
# key :  bracket_id length :  8624
# key :  comment length :  8624
# key :  like_cnt length :  8624
# key :  dislike_cnt length :  8624
# key :  date length :  8624
# key :  user_id length :  8624

# %%
pd.DataFrame(dic)
# Out:
#         title  episode   nickname bracket_id  \
# 0     유미의 세포들      328          나   titi****
# 1     유미의 세포들      328  Guest3151   34ja****
# 2     유미의 세포들      328  Guest3151   34ja****
# 3     유미의 세포들      328  Guest3151   34ja****
# 4     유미의 세포들      328        이준이   tjrd****
# 5     유미의 세포들      328        이준이   tjrd****
# 6     유미의 세포들      328        이준이   tjrd****
# 7     유미의 세포들      328        이준이   tjrd****
# 8     유미의 세포들      328  내 이름은 김유미   tiff****
# 9     유미의 세포들      328          꺅   cind****
# 10    유미의 세포들      328          꺅   cind****
# 11    유미의 세포들      328         우아   kims****
# 12    유미의 세포들      328       정부아늬   choi****
# 13    유미의 세포들      328       정부아늬   choi****
# 14    유미의 세포들      328        정후니   jung****
